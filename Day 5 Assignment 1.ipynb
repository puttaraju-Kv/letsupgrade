# %%
def s_l(l, s):
   s_s = "It's gone"
   if s==[]:
       s_s = "It's a Match"
   elif s == 1:
       s_s = "It's a Match"
   elif len(s) > len(l):
       s_s = "It's gone"
   else:
        for i in range(len(l)):
            if l[i] == s[0]:
                n = 1
                while ( n < len(s)) and (l[i+n] == s[n]):
                    n += 1

                if n == len(s):
                    s_s = "It's a Match"  
   return s_s



print(s_l(l1, l2))
# Out:
# It's a Match

# %%
s_l([0,1,2,3,4,5], [0,1,2])
# Out:
# "It's a Match"

# %%
s_l([0,1,2,3,4,5], [0,1,8])
# Out:
# "It's gone"
