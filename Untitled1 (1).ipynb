# %%
a=2
type(a)
# Out:
# int

# %%
a=1.2
type(a)
# Out:
# float

# %%
a="putta"
type(a)
# Out:
# str

# %%
str="putta raju"
print(str)
# Out:
# putta raju

# %% [raw]
# str.capitalize()

# %%
str.count("k")
# Out:
# 0

# %%
str.endswith("d")
# Out:
# False

# %%
str.find("d")
# Out:
# -1

# %%
str.index("p")
# Out:
# 0

# %%
str.isupper()
# Out:
# False

# %%
str.isalnum()
# Out:
# False

# %%
str.isascii()
# Out:
# True

# %% [raw]
# str.lower()

# %%
str.split()
# Out:
# ['putta', 'raju']

# %%
str.upper()
# Out:
# 'PUTTA RAJU'

# %%
ist=[1,1.2,"putta",[3,3.4,"raju"]]
print(ist)
# Out:
# [1, 1.2, 'putta', [3, 3.4, 'raju']]

# %%
ist.append(5)
print(ist)
# Out:
# [1, 1.2, 'putta', [3, 3.4, 'raju'], 5]

# %%
ist.index(ist[2])
# Out:
# 2

# %% [raw]
# ist.remove(7)
# print(ist)

# %%
ist.pop(ist[0])
print(ist)
[1,'putta',[3,3.4,'raju'],'putta',1]
# Out:
# [1, 'putta', [3, 3.4, 'raju'], 5]
# [1, 'putta', [3, 3.4, 'raju'], 'putta', 1]

# %%
ist.extend([1.2])

# %%
ist.remove(5)
print(ist)
# Out:
# [1, 'putta', [3, 3.4, 'raju'], 1.2]

# %%
print(dic["name"])
putta
# Out:
# putta
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-eea5716271e4> in <module>
#       1 print(dic["name"])
# ----> 2 putta
#
# NameError: name 'putta' is not defined

# %%
dic.get("last name")
# Out:
# 'raju'

# %%
dic={"name":"putta","last name":"raju","p no":"1234567890"}

# %%
dic.fromkeys("P no")
# Out:
# {'P': None, ' ': None, 'n': None, 'o': None}

# %%
dic.items()
# Out:
# dict_items([('name', 'putta'), ('last name', 'raju'), ('p no', '1234567890')])

# %%
dic.pop("name")
# Out:
# 'putta'

# %%
print(dic)
# Out:
# {'last name': 'raju', 'p no': '1234567890'}

# %%
dic.update({"name":"putta"})
print(dic)
# Out:
# {'last name': 'raju', 'p no': '1234567890', 'name': 'putta'}

# %%
dic={"name":"putta","last name":"raju","p no":"1234567890"}
print(dic)
# Out:
# {'name': 'putta', 'last name': 'raju', 'p no': '1234567890'}

# %%
dic.values()
# Out:
# dict_values(['putta', 'raju', '1234567890'])

# %%
dic.keys()
# Out:
# dict_keys(['name', 'last name', 'p no'])

# %%
dic.fromkeys("name")
# Out:
# {'n': None, 'a': None, 'm': None, 'e': None}

# %%
# for sets

# %%
s = {"putta", 1,1.2}
print(s)
# Out:
# {1.2, 'putta', 1}

# %%
s.add("raj")
print(s)
# Out:
# {1.2, 'putta', 'raj', 1}

# %%
s1 = {2,1,"raj"}
print(s1)
# Out:
# {1, 2, 'raj'}

# %%
s.difference(s1)
# Out:
# {1.2, 'putta'}

# %%
s.intersection(s1)
# Out:
# {1, 'raj'}

# %%
s.remove("putta")

# %%
print(s)
# Out:
# {1.2, 'raj', 1}

# %%
s.pop()
# Out:
# 1.2

# %%
s.union(s1)
# Out:
# {1, 2, 'raj'}

# %%
s.update("kv")

# %%
print(s)
# Out:
# {1, 'v', 'k', 'raj'}

# %%
# for tuple

# %%
t = (1,1.2,"raj")
print(t)
# Out:
# (1, 1.2, 'raj')

# %%
t.count(1)
# Out:
# 1

# %%
t.index("raj")
# Out:
# 2
